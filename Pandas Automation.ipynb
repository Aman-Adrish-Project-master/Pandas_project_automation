# %%
import pandas as pd

# %%
input_file=pd.read_excel('Input.xlsx')
input_file.head(4)
# Out:
#            sku  List Price  Map Price           UPC  \
# 0   LCACBABL26         NaN        NaN  721535754373
# 1   LCACBABL30         NaN        NaN  721535754380
# 2  LCACBABRK26         NaN        NaN  721535754397
# 3  LCACBABRK30         NaN        NaN  721535754403
#
#                                                Title  \
# 0  Indoor Outdoor Bar Stool with Rounded Rope Wov...
# 1  30 Inch Indoor Outdoor Bar Stool with Rounded ...
# 2  Indoor Outdoor Bar Stool with Rounded Rope Wov...
# 3  30 Inch Indoor Outdoor Bar Stool with Rounded ...
#
#                                          Description      Material   Color  \
# 0  Sit back and relax with the inclusion of this ...  Metal, Rope   Black
# 1  Sit back and relax with the inclusion of this ...  Metal, Rope   Black
# 2  Sit back and relax with the inclusion of this ...  Metal, Rope    Pink
# 3  Sit back and relax with the inclusion of this ...  Metal, Rope    Pink
#
# ...

# %%
output_file=pd.read_excel('output.xlsx')
output_file.head(4)
# Out:
# Empty DataFrame
# Columns: [Vendor1 Name, Vendor1 Drop Ship, SKU, Adjust Vendor Inventory, Vendor1 SKU, Vendor1 list Price, Vendor1 Map Policy, Vendor1 Map Price, Vendor1 Drop Ship Fee, UPC, Name, Keywords, Description, Material Used, Color, Finish, Bullet 1, Bullet 2, Bullet 3, Bullet 4, Bullet 5, Bullet 6, Bullet 7, Bullet 8, Bullet 9, Category Id, Brand, ASIN Number, Harmonized Code, Year Catalogued, Country Of Origin, Weight1, Length1, Width1, Height1, Length2, Width2, Height2, DIM1, DIM2, Assembly Required, Actual Outbound Shipping Cost, Ship Method, Ship Weight1, Ship Length1, Ship Width1, Ship Height1, Ship Weight2, Ship Length2, Ship Width2, Ship Height2, Discontinued, Handling Time, Received As, Qty Per Case, Sold As, Qty Per Set, Taxonomy Node, Active, Status, Vendor Type]
# Index: []
#
# [0 rows x 61 columns]

# %%
vendor_sku=input_file['sku']
vendor_sku.head(4)
# Out:
# 0     LCACBABL26
# 1     LCACBABL30
# 2    LCACBABRK26
# 3    LCACBABRK30
# Name: sku, dtype: object

# %%
output_file['Vendor1 SKU']=vendor_sku
output_file.head(4)
# Out:
#   Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory  Vendor1 SKU  \
# 0          NaN               NaN  NaN                     NaN   LCACBABL26
# 1          NaN               NaN  NaN                     NaN   LCACBABL30
# 2          NaN               NaN  NaN                     NaN  LCACBABRK26
# 3          NaN               NaN  NaN                     NaN  LCACBABRK30
#
#   Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
#
#   Vendor1 Drop Ship Fee  UPC  ... Discontinued Handling Time Received As  \
# 0                   NaN  NaN  ...          NaN           NaN         NaN
# 1                   NaN  NaN  ...          NaN           NaN         NaN
# 2                   NaN  NaN  ...          NaN           NaN         NaN
# ...

# %%
output_file.rename(columns={'Vendor1 SKU':'sku'}, inplace=True)

# %%
output_file.head(4)
# Out:
#   Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory          sku  \
# 0          NaN               NaN  NaN                     NaN   LCACBABL26
# 1          NaN               NaN  NaN                     NaN   LCACBABL30
# 2          NaN               NaN  NaN                     NaN  LCACBABRK26
# 3          NaN               NaN  NaN                     NaN  LCACBABRK30
#
#   Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
#
#   Vendor1 Drop Ship Fee  UPC  ... Discontinued Handling Time Received As  \
# 0                   NaN  NaN  ...          NaN           NaN         NaN
# 1                   NaN  NaN  ...          NaN           NaN         NaN
# 2                   NaN  NaN  ...          NaN           NaN         NaN
# ...

# %%
df=pd.merge(output_file,input_file,on='sku',how='left')

# %%
df
# Out:
#    Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory          sku  \
# 0           NaN               NaN  NaN                     NaN   LCACBABL26
# 1           NaN               NaN  NaN                     NaN   LCACBABL30
# 2           NaN               NaN  NaN                     NaN  LCACBABRK26
# 3           NaN               NaN  NaN                     NaN  LCACBABRK30
# 4           NaN               NaN  NaN                     NaN   LCACBAGR26
# 5           NaN               NaN  NaN                     NaN   LCACBAGR30
# 6           NaN               NaN  NaN                     NaN  LCACBAWSB26
# 7           NaN               NaN  NaN                     NaN  LCACBAWSB30
# 8           NaN               NaN  NaN                     NaN     LCACSIBL
# 9           NaN               NaN  NaN                     NaN    LCACSIBRK
# 10          NaN               NaN  NaN                     NaN    LCACSIGRY
# ...

# %%
output_file.columns
# Out:
# Index(['Vendor1 Name', 'Vendor1 Drop Ship', 'SKU', 'Adjust Vendor Inventory',
#        'sku', 'Vendor1 list Price', 'Vendor1 Map Policy', 'Vendor1 Map Price',
#        'Vendor1 Drop Ship Fee', 'UPC', 'Name', 'Keywords', 'Description',
#        'Material Used', 'Color', 'Finish', 'Bullet 1', 'Bullet 2', 'Bullet 3',
#        'Bullet 4', 'Bullet 5', 'Bullet 6', 'Bullet 7', 'Bullet 8', 'Bullet 9',
#        'Category Id', 'Brand', 'ASIN Number', 'Harmonized Code',
#        'Year Catalogued', 'Country Of Origin', 'Weight1', 'Length1', 'Width1',
#        'Height1', 'Length2', 'Width2', 'Height2', 'DIM1', 'DIM2',
#        'Assembly Required', 'Actual Outbound Shipping Cost', 'Ship Method',
#        'Ship Weight1', 'Ship Length1', 'Ship Width1', 'Ship Height1',
#        'Ship Weight2', 'Ship Length2', 'Ship Width2', 'Ship Height2',
#        'Discontinued', 'Handling Time', 'Received As', 'Qty Per Case',
#        'Sold As', 'Qty Per Set', 'Taxonomy Node', 'Active', 'Status',
# ...

# %%
input_file.columns
# Out:
# Index(['sku', 'List Price', 'Map Price', 'UPC', 'Title', 'Description',
#        'Material', 'Color', 'Bullet1', 'Bullet2', 'Bullet3', 'Bullet4',
#        'Bullet5', 'Bullet6', 'Bullet7', 'Bullet8', 'Bullet9', 'Bullet10',
#        'Country Of Origin', 'Assembly Required', 'Weight1', 'Length1',
#        'Width1', 'Height1', 'Weight2', 'Length2', 'Width2', 'Height2',
#        'Weight3', 'Length3', 'Width3', 'Height3', 'Ship Weight1',
#        'Ship Length1', 'Ship Width1', 'Ship Height1', 'Ship Weight2',
#        'Ship Length2', 'Ship Width2', 'Ship Height2', 'Ship Weight3',
#        'Ship Length3', 'Ship Width3', 'Ship Height3'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Vendor1 Name', 'Vendor1 Drop Ship', 'SKU', 'Adjust Vendor Inventory',
#        'sku', 'Vendor1 list Price', 'Vendor1 Map Policy', 'Vendor1 Map Price',
#        'Vendor1 Drop Ship Fee', 'UPC_x',
#        ...
#        'Ship Width1_y', 'Ship Height1_y', 'Ship Weight2_y', 'Ship Length2_y',
#        'Ship Width2_y', 'Ship Height2_y', 'Ship Weight3', 'Ship Length3',
#        'Ship Width3', 'Ship Height3'],
#       dtype='object', length=104)

# %%
#cols=output_file.columns.to_list()
#cols

# %%
#cols.append('UPC_y')
#cols

# %%
output_file['UPC']=df['UPC_y']
output_file['Name']=df['Title']
output_file['Description']=df['Description_y']
output_file['Material Used']=df['Material']
output_file['Color']=df['Color_y']
output_file['Bullet 1']=df['Bullet1']
output_file['Bullet 2']=df['Bullet2']
output_file['Bullet 3']=df['Bullet3']
output_file['Bullet 4']=df['Bullet4']
output_file['Bullet 5']=df['Bullet5']
output_file['Bullet 6']=df['Bullet6']
output_file['Bullet 7']=df['Bullet7']
output_file['Bullet 8']=df['Bullet8']
output_file['Bullet 9']=df['Bullet9']
output_file['Country Of Origin']=df['Country Of Origin_y']
output_file['Assembly Required']=df['Assembly Required_y']

# %%
pd.set_option('display.max_columns', None)
#output_file

# %%
output_file.head(5)
# Out:
#   Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory          sku  \
# 0          NaN               NaN  NaN                     NaN   LCACBABL26
# 1          NaN               NaN  NaN                     NaN   LCACBABL30
# 2          NaN               NaN  NaN                     NaN  LCACBABRK26
# 3          NaN               NaN  NaN                     NaN  LCACBABRK30
# 4          NaN               NaN  NaN                     NaN   LCACBAGR26
#
#   Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
# 4                NaN                NaN               NaN
#
#   Vendor1 Drop Ship Fee           UPC  \
# 0                   NaN  721535754373
# 1                   NaN  721535754380
# 2                   NaN  721535754397
# ...

# %%
df.head(6)
# Out:
#   Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory          sku  \
# 0          NaN               NaN  NaN                     NaN   LCACBABL26
# 1          NaN               NaN  NaN                     NaN   LCACBABL30
# 2          NaN               NaN  NaN                     NaN  LCACBABRK26
# 3          NaN               NaN  NaN                     NaN  LCACBABRK30
# 4          NaN               NaN  NaN                     NaN   LCACBAGR26
# 5          NaN               NaN  NaN                     NaN   LCACBAGR30
#
#   Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
# 4                NaN                NaN               NaN
# 5                NaN                NaN               NaN
#
# ...

# %%
df_prefix=pd.read_excel('Prefix.xlsx')

# %%
df_prefix.head(5)
# Out:
#   Vendor or Supplier Or Pico W/H Name Pick Ticket column
# 0                      UMA Enterprise                UMA
# 1                         4D Concepts                4DC
# 2                         Alpine Corp                ALP
# 3                    Amrapur Overseas                AMP
# 4                        Armen Living                AML

# %%
df_prefix['Vendor or Supplier Or Pico W/H Name']=df_prefix['Vendor or Supplier Or Pico W/H Name'].str.lower()

# %%
df_prefix.head(3)
# Out:
#   Vendor or Supplier Or Pico W/H Name Pick Ticket column
# 0                      uma enterprise                UMA
# 1                         4d concepts                4DC
# 2                         alpine corp                ALP

# %%
df_prefix.set_index('Vendor or Supplier Or Pico W/H Name',inplace=True)

# %%
input_vendor_name=input('Enter the name of the vendor\n')

try:
    pick_ticket=df_prefix.loc[input_vendor_name,'Pick Ticket column']
    print(pick_ticket)
except:
    print('name not found')
# Out:
# Enter the name of the vendor
# modway furniture
# MDY

# %%
dropship_list=["convineince concepts", "furrino", "modway furniture", "moe's home", "wholesale interior"]

# %%
if input_vendor_name in dropship_list:
    output_file['Vendor1 Drop Ship']="Yes"
else:
    output_file['Vendor1 Drop Ship']="No"

# %%
output_file.head(4)
# Out:
#   Vendor1 Name Vendor1 Drop Ship  SKU Adjust Vendor Inventory          sku  \
# 0          NaN               Yes  NaN                     NaN   LCACBABL26
# 1          NaN               Yes  NaN                     NaN   LCACBABL30
# 2          NaN               Yes  NaN                     NaN  LCACBABRK26
# 3          NaN               Yes  NaN                     NaN  LCACBABRK30
#
#   Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0                NaN                NaN               NaN
# 1                NaN                NaN               NaN
# 2                NaN                NaN               NaN
# 3                NaN                NaN               NaN
#
#   Vendor1 Drop Ship Fee           UPC  \
# 0                   NaN  721535754373
# 1                   NaN  721535754380
# 2                   NaN  721535754397
# 3                   NaN  721535754403
#
#                                                 Name Keywords  \
# ...

# %%
output_file['SKU']=pick_ticket+"-"+output_file['sku']

# %%
output_file.head(4)
# Out:
#   Vendor1 Name Vendor1 Drop Ship              SKU Adjust Vendor Inventory  \
# 0          NaN               Yes   MDY-LCACBABL26                     NaN
# 1          NaN               Yes   MDY-LCACBABL30                     NaN
# 2          NaN               Yes  MDY-LCACBABRK26                     NaN
# 3          NaN               Yes  MDY-LCACBABRK30                     NaN
#
#            sku Vendor1 list Price Vendor1 Map Policy Vendor1 Map Price  \
# 0   LCACBABL26                NaN                NaN               NaN
# 1   LCACBABL30                NaN                NaN               NaN
# 2  LCACBABRK26                NaN                NaN               NaN
# 3  LCACBABRK30                NaN                NaN               NaN
#
#   Vendor1 Drop Ship Fee           UPC  \
# 0                   NaN  721535754373
# 1                   NaN  721535754380
# 2                   NaN  721535754397
# 3                   NaN  721535754403
#
# ...
